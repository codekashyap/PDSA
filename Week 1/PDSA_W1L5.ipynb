# %% [markdown]
# ## GCD

# %%
def gcd(m, n):
  a = max(m, n)
  b = min(m, n)

  if a % b == 0:
    return b
  
  return gcd(b, a - b)

# %% [markdown]
# ### Euclid's algorithm

# %%
def gcd(m, n):
  a = max(m, n)
  b = min(m, n)

  if a % b == 0:
    return b
  
  return gcd(b, a % b)
